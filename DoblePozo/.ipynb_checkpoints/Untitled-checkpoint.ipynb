# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit
from pylab import *

# %%
Data=pd.read_csv('Distribucion_t_pos.csv')

# %%
plt.figure(figsize=(10,10))
numbins=102
n, bins, patches = plt.hist(Data.loc[:,"x"], numbins, density=True, facecolor='g', alpha=0.5) 
plt.xlabel('Tiempo')
plt.ylabel('Distribunción de tiempos')
plt.grid(True)
plt.savefig("Distribucion positiva de tiempos.png")

# %%
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit
from pylab import *

# El nombre con el que se guardan las gráficas
# Pongo k_b*T=0.2
T=0.2
# Cargo los datos
Data=pd.read_csv('Data/Probabilidades.csv')
plot(Data.loc[:,"F"],Data.loc[:,"-x"])
