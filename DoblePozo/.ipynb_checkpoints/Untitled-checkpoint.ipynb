# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import matplotlib.mlab as mlab
import numpy as np
import pandas as pd

# %%
Data=pd.read_csv('Data.csv')

# %%
n, bins, patches = plt.hist(Data.loc[:,"Posicion"], 60, density=True, facecolor='g', alpha=0.5) 
np.histogram(a,bins = 60) 
hist,bins = np.histogram(a,bins = 60) 
x = np.linspace(min(bins), max(bins), 60)
plt.plot(x,hist)
plt.xlabel('Posicion')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()

# %%
hist,bins = np.histogram(Data.loc[:,"Posicion"],bins = 60)
print(bins)
# Out:
# [-1.749      -1.69181667 -1.63463333 -1.57745    -1.52026667 -1.46308333
#  -1.4059     -1.34871667 -1.29153333 -1.23435    -1.17716667 -1.11998333
#  -1.0628     -1.00561667 -0.94843333 -0.89125    -0.83406667 -0.77688333
#  -0.7197     -0.66251667 -0.60533333 -0.54815    -0.49096667 -0.43378333
#  -0.3766     -0.31941667 -0.26223333 -0.20505    -0.14786667 -0.09068333
#  -0.0335      0.02368333  0.08086667  0.13805     0.19523333  0.25241667
#   0.3096      0.36678333  0.42396667  0.48115     0.53833333  0.59551667
#   0.6527      0.70988333  0.76706667  0.82425     0.88143333  0.93861667
#   0.9958      1.05298333  1.11016667  1.16735     1.22453333  1.28171667
#   1.3389      1.39608333  1.45326667  1.51045     1.56763333  1.62481667
#   1.682     ]

# %%
import numpy as np 
Data=pd.read_csv('Data.csv')
numbins=60
hist,bins = np.histogram(a,bins = numbins) 
Paso=bins[1]-bins[0]
xData=np.arange(min(bins)+Paso/2,max(bins),Paso)
print(xData)
print(hist)
plt.plot(xData,hist)
# Out:
# [-1.72040833 -1.663225   -1.60604167 -1.54885833 -1.491675   -1.43449167
#  -1.37730833 -1.320125   -1.26294167 -1.20575833 -1.148575   -1.09139167
#  -1.03420833 -0.977025   -0.91984167 -0.86265833 -0.805475   -0.74829167
#  -0.69110833 -0.633925   -0.57674167 -0.51955833 -0.462375   -0.40519167
#  -0.34800833 -0.290825   -0.23364167 -0.17645833 -0.119275   -0.06209167
#  -0.00490833  0.052275    0.10945833  0.16664167  0.223825    0.28100833
#   0.33819167  0.395375    0.45255833  0.50974167  0.566925    0.62410833
#   0.68129167  0.738475    0.79565833  0.85284167  0.910025    0.96720833
#   1.02439167  1.081575    1.13875833  1.19594167  1.253125    1.31030833
#   1.36749167  1.424675    1.48185833  1.53904167  1.596225    1.65340833]
# [    27     60    404   1743   4847  12126  24479  45938  73367 104944
#  139651 159521 174913 173702 166238 149938 132233 106457  89267  73383
#   58333  48277  37789  31403  26737  22403  19812  17814  15850  14793
# ...
